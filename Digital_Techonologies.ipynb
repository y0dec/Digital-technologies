# %% [markdown]
# <a href="https://colab.research.google.com/github/y0dec/Digital-technologies/blob/main/Digital_Techonologies.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Пример использования MarkDown
#
# Нужно сделать:
#
# 1.
#
# *   НГТУ
# *   НГУ
# *   СГУПС
# *   СГУВТ
#
#
# 2.
#
# ![medium_a68ad9662fbc4b06311a7297c5321cdf.png](data:image/png;base64,...)
#
# 3.
#
#   A  | B| C
# -------------------|--------------------|------------------
# 22     | 42      | 67
# 33       | 65       | 12
#
# 4.
#
# [repository github](https://github.com/y0dec/Digital-technologies)
